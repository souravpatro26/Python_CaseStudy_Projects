# %% [markdown]
# # Basic Exercises on Data Importing - Understanding - Manipulating - Analysis - Visualization

# %% [markdown]
# ## Section-1: The pupose of the below exercises (1-7) is to create dictionary and convert into dataframes, how to diplay etc...
# ## The below exercises required to create data

# %% [markdown]
# ### 1. Import the necessary libraries (pandas, numpy, datetime, re etc)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import re

# set the graphs to show in the jupyter notebook
# %matplotlib inline

# set seabor graphs to a better style
sns.set(style="ticks")

# %% [markdown]
# ### 2. Run the below line of code to create a dictionary and this will be used for below exercises

# %%
raw_data = {"name": ['Bulbasaur', 'Charmander','Squirtle','Caterpie'],
            "evolution": ['Ivysaur','Charmeleon','Wartortle','Metapod'],
            "type": ['grass', 'fire', 'water', 'bug'],
            "hp": [45, 39, 44, 45],
            "pokedex": ['yes', 'no','yes','no']                        
            }

# %% [markdown]
# ### 3. Assign it to a object called pokemon and it should be a pandas DataFrame

# %%
pokemon = pd.DataFrame(raw_data)
pokemon
# Out:
#          name   evolution   type  hp pokedex
# 0   Bulbasaur     Ivysaur  grass  45     yes
# 1  Charmander  Charmeleon   fire  39      no
# 2    Squirtle   Wartortle  water  44     yes
# 3    Caterpie     Metapod    bug  45      no

# %% [markdown]
# ### 4. If the DataFrame columns are in alphabetical order, change the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[['name','type','hp','evolution','pokedex']]
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ### 5. Add another column called place, and insert places (lakes, parks, hills, forest etc) of your choice.

# %%
pokemon['place']=['lakes','parks','hills','forest']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12464\2436246581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pokemon['place']=['lakes','parks','hills','forest']

# %%
pokemon.insert(4,'place',['lakes','parks','hills','forest'])

# %% [markdown]
# ### 6. Display the data type of each column

# %%
pokemon.dtypes

# %% [markdown]
# ### 7. Display the info of dataframe

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4 non-null      object
#  1   type       4 non-null      object
#  2   hp         4 non-null      int64
#  3   evolution  4 non-null      object
#  4   pokedex    4 non-null      object
#  5   place      4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 320.0+ bytes

# %% [markdown]
# ## Section-2: The pupose of the below exercise (8-20) is to understand deleting data with pandas.
# ## The below exercises required to use wine.data

# %% [markdown]
# ### 8. Import the dataset *wine.txt* from the folder and assign it to a object called wine
#
# Please note that the original data text file doesn't contain any header. Please ensure that when you import the data, you should use a suitable argument so as to avoid data getting imported as header.

# %%
wine = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/wine.txt',header= None)

# %% [markdown]
# ### 9. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.drop(columns=[0,3,6,8,10,12,13],inplace=True)
wine
# Out:
#         1     2     4    5     7     9     11
# 0    14.23  1.71  15.6  127  3.06  2.29  1.04
# 1    13.20  1.78  11.2  100  2.76  1.28  1.05
# 2    13.16  2.36  18.6  101  3.24  2.81  1.03
# 3    14.37  1.95  16.8  113  3.49  2.18  0.86
# 4    13.24  2.59  21.0  118  2.69  1.82  1.04
# ..     ...   ...   ...  ...   ...   ...   ...
# 173  13.71  5.65  20.5   95  0.61  1.06  0.64
# 174  13.40  3.91  23.0  102  0.75  1.41  0.70
# 175  13.27  4.28  20.0  120  0.69  1.35  0.59
# 176  13.17  2.59  20.0  120  0.68  1.46  0.60
# 177  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### 10. Assign the columns as below:
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol','malic_acid','alcalinity_of_ash','magnesium','flavanoids','proanthocyanins','hue']
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      14.23        1.71               15.6        127        3.06
# 1      13.20        1.78               11.2        100        2.76
# 2      13.16        2.36               18.6        101        3.24
# 3      14.37        1.95               16.8        113        3.49
# 4      13.24        2.59               21.0        118        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5         95        0.61
# 174    13.40        3.91               23.0        102        0.75
# 175    13.27        4.28               20.0        120        0.69
# 176    13.17        2.59               20.0        120        0.68
# 177    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### 11. Set the values of the first 3 values from alcohol column as NaN

# %%
wine.alcohol.iloc[0:3] = np.NaN
wine
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1772\1932103850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine.alcohol.iloc[0:3] = np.NaN
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.71               15.6        127        3.06
# 1        NaN        1.78               11.2        100        2.76
# 2        NaN        2.36               18.6        101        3.24
# 3      14.37        1.95               16.8        113        3.49
# 4      13.24        2.59               21.0        118        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5         95        0.61
# 174    13.40        3.91               23.0        102        0.75
# 175    13.27        4.28               20.0        120        0.69
# 176    13.17        2.59               20.0        120        0.68
# 177    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### 12. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.magnesium.iloc[2:4] = np.NaN
wine
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1772\2558512475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine.magnesium.iloc[2:4] = np.NaN
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.71               15.6      127.0        3.06
# 1        NaN        1.78               11.2      100.0        2.76
# 2        NaN        2.36               18.6        NaN        3.24
# 3      14.37        1.95               16.8        NaN        3.49
# 4      13.24        2.59               21.0      118.0        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5       95.0        0.61
# 174    13.40        3.91               23.0      102.0        0.75
# 175    13.27        4.28               20.0      120.0        0.69
# 176    13.17        2.59               20.0      120.0        0.68
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### 13. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.alcohol.fillna(10,inplace= True)
wine.magnesium.fillna(100,inplace =True)
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.71               15.6      127.0        3.06
# 1      10.00        1.78               11.2      100.0        2.76
# 2      10.00        2.36               18.6      100.0        3.24
# 3      14.37        1.95               16.8      100.0        3.49
# 4      13.24        2.59               21.0      118.0        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5       95.0        0.61
# 174    13.40        3.91               23.0      102.0        0.75
# 175    13.27        4.28               20.0      120.0        0.69
# 176    13.17        2.59               20.0      120.0        0.68
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### 14. Count the number of missing values in all columns.

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### 15.  Create an array of 10 random numbers up until 10 and save it.

# %%
rand =np.random.randint(0,10,10)
rand
# Out:
# array([4, 0, 4, 2, 3, 9, 7, 5, 9, 8])

# %% [markdown]
# ### 16.  Set the rows corresponding to the random numbers to NaN in the column *alcohol*

# %%
wine.alcohol.iloc[rand] = np.NaN
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.71               15.6      127.0        3.06
# 1      10.00        1.78               11.2      100.0        2.76
# 2        NaN        2.36               18.6      100.0        3.24
# 3        NaN        1.95               16.8      100.0        3.49
# 4        NaN        2.59               21.0      118.0        2.69
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5       95.0        0.61
# 174    13.40        3.91               23.0      102.0        0.75
# 175    13.27        4.28               20.0      120.0        0.69
# 176    13.17        2.59               20.0      120.0        0.68
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.29  1.04
# 1               1.28  1.05
# 2               2.81  1.03
# 3               2.18  0.86
# 4               1.82  1.04
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [178 rows x 7 columns]

# %% [markdown]
# ### 17.  How many missing values do we have now?

# %%
wine.isnull().sum()
# Out:
# alcohol              8
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### 18. Print only the non-null values in alcohol

# %%
wine.loc[wine.alcohol.notnull(),'alcohol']
# Out:
# 1      10.00
# 6      14.39
# 10     14.10
# 11     14.12
# 12     13.75
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcohol, Length: 170, dtype: float64

# %% [markdown]
# ### 19. Delete the rows that contain missing values

# %%
wine.dropna(axis=0, inplace=True)
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 1      10.00        1.78               11.2      100.0        2.76
# 6      14.39        1.87               14.6       96.0        2.52
# 10     14.10        2.16               18.0      105.0        3.32
# 11     14.12        1.48               16.8       95.0        2.43
# 12     13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 173    13.71        5.65               20.5       95.0        0.61
# 174    13.40        3.91               23.0      102.0        0.75
# 175    13.27        4.28               20.0      120.0        0.69
# 176    13.17        2.59               20.0      120.0        0.68
# 177    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 1               1.28  1.05
# 6               1.98  1.02
# 10              2.38  1.25
# 11              1.57  1.17
# 12              1.81  1.15
# ..               ...   ...
# 173             1.06  0.64
# 174             1.41  0.70
# 175             1.35  0.59
# 176             1.46  0.60
# 177             1.35  0.61
#
# [170 rows x 7 columns]

# %% [markdown]
# ### 20.  Reset the index, so it starts with 0 again

# %%
wine.reset_index(drop= True)
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1      14.39        1.87               14.6       96.0        2.52
# 2      14.10        2.16               18.0      105.0        3.32
# 3      14.12        1.48               16.8       95.0        2.43
# 4      13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 165    13.71        5.65               20.5       95.0        0.61
# 166    13.40        3.91               23.0      102.0        0.75
# 167    13.27        4.28               20.0      120.0        0.69
# 168    13.17        2.59               20.0      120.0        0.68
# 169    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               1.98  1.02
# 2               2.38  1.25
# 3               1.57  1.17
# 4               1.81  1.15
# ..               ...   ...
# 165             1.06  0.64
# 166             1.41  0.70
# 167             1.35  0.59
# 168             1.46  0.60
# 169             1.35  0.61
#
# [170 rows x 7 columns]

# %% [markdown]
# ## Section-3: The pupose of the below exercise (21-27) is to understand ***filtering & sorting*** data from dataframe.
# ## The below exercises required to use chipotle.tsv

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Import the dataset directly from this link (https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and create dataframe called chipo

# %%
chipo =pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/chipotle.tsv',sep = '\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### 21. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$','').apply(pd.to_numeric)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9172\947991520.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipo['item_price'] = chipo['item_price'].str.replace('$','').apply(pd.to_numeric)

# %%
chipo['price_per_item'] = chipo['item_price']/chipo['quantity']

# %%
chipo[chipo.price_per_item > 10]['item_name'].nunique()
# Out:
# 25

# %% [markdown]
# ### 22. Print the Chipo Dataframe & info about data frame

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ### 23. What is the price of each item?
# - Delete the duplicates in item_name and quantity
# - Print a data frame with only two columns `item_name` and `item_price`
# - Sort the values from the most to less expensive

# %%
chipo.drop_duplicates(subset = ['item_name','quantity'],inplace = True)

# %%
chipo1 = chipo[['item_name','item_price']]

# %%
chipo1.sort_values('item_price', ascending = False)
# Out:
#                          item_name  item_price
# 3598  Chips and Fresh Tomato Salsa       44.25
# 3480                 Carnitas Bowl       35.25
# 1254               Chicken Burrito       35.00
# 3601                Veggie Burrito       33.75
# 409                   Chicken Bowl       32.94
# ...                            ...         ...
# 40                           Chips        2.15
# 6                    Side of Chips        1.69
# 263              Canned Soft Drink        1.25
# 34                   Bottled Water        1.09
# 28                     Canned Soda        1.09
#
# [103 rows x 2 columns]

# %% [markdown]
# ### 24. Sort by the name of the item

# %%
chipo1.sort_values(by = 'item_name')
# Out:
#                   item_name  item_price
# 298       6 Pack Soft Drink        6.49
# 3389      6 Pack Soft Drink       12.98
# 39            Barbacoa Bowl       11.75
# 21         Barbacoa Burrito        8.99
# 1903  Barbacoa Crispy Tacos       18.50
# ...                     ...         ...
# 1653    Veggie Crispy Tacos        8.49
# 1694           Veggie Salad        8.49
# 186       Veggie Salad Bowl       11.25
# 3889      Veggie Soft Tacos       16.98
# 738       Veggie Soft Tacos       11.25
#
# [103 rows x 2 columns]

# %% [markdown]
# ### 25. What was the quantity of the most expensive item ordered?

# %%
chipo[chipo.item_price == chipo.item_price.max()] ['quantity'].reset_index()
# Out:
#    index  quantity
# 0   3598        15

# %% [markdown]
# ### 26. How many times were a Veggie Salad Bowl ordered?

# %%
chipo[chipo.item_name == 'Veggie Salad Bowl'].shape[0]
# Out:
# 1

# %% [markdown]
# ### 27. How many times people orderd more than one Canned Soda?

# %%
chipo[(chipo.item_name =='Canned Soda') & (chipo.quantity > 1)]['order_id'].count()
# Out:
# 2

# %% [markdown]
# ## Section-4: The purpose of the below exercises is to understand how to perform aggregations of data frame
# ## The below exercises (28-33) required to use occupation.csv

# %% [markdown]
# ###  28. Import the dataset occupation.csv and assign object as users

# %%
users = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/occupation.csv', sep = '|')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### 29. Discover what is the mean age per occupation

# %%
users.groupby('occupation').agg({'age':'mean'}).reset_index()
# Out:
#        occupation        age
# 0   administrator  38.746835
# 1          artist  31.392857
# 2          doctor  43.571429
# 3        educator  42.010526
# 4        engineer  36.388060
# 5   entertainment  29.222222
# 6       executive  38.718750
# 7      healthcare  41.562500
# 8       homemaker  32.571429
# 9          lawyer  36.750000
# 10      librarian  40.000000
# 11      marketing  37.615385
# 12           none  26.555556
# 13          other  34.523810
# 14     programmer  33.121212
# 15        retired  63.071429
# 16       salesman  35.666667
# 17      scientist  35.548387
# 18        student  22.081633
# 19     technician  33.148148
# 20         writer  36.311111

# %% [markdown]
# ### 30. Discover the Male ratio per occupation and sort it from the most to the least.
#
# Use numpy.where() to encode gender column.

# %%
pd.DataFrame(occ_gender_count.loc[: : ,'Male%']).sort_values( by = 'Male%', ascending =False).reset_index()
# Out:
#        occupation       Male%
# 0          doctor  100.000000
# 1        engineer   97.014925
# 2      technician   96.296296
# 3         retired   92.857143
# 4      programmer   90.909091
# 5       executive   90.625000
# 6       scientist   90.322581
# 7   entertainment   88.888889
# 8          lawyer   83.333333
# 9        salesman   75.000000
# 10       educator   72.631579
# 11        student   69.387755
# 12          other   65.714286
# 13      marketing   61.538462
# 14         writer   57.777778
# 15           none   55.555556
# 16  administrator   54.430380
# 17         artist   53.571429
# 18      librarian   43.137255
# 19     healthcare   31.250000
# 20      homemaker   14.285714

# %% [markdown]
# ### 31. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### 32. For each combination of occupation and gender, calculate the mean age

# %%
pd.DataFrame(users.groupby(['occupation','gender']).age.mean())
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# programmer    F       32.166667
#               M       33.216667
# retired       F       70.000000
#               M       62.538462
# salesman      F       27.000000
#               M       38.555556
# scientist     F       28.333333
#               M       36.321429
# student       F       20.750000
#               M       22.669118
# technician    F       38.000000
#               M       32.961538
# writer        F       37.631579
#               M       35.346154

# %% [markdown]
# ### 33.  For each occupation present the percentage of women and men

# %%
occ_gender_count = pd.crosstab(index=users.occupation, columns = users.gender)
occ_gender_count
# Out:
# gender          F    M
# occupation
# administrator  36   43
# artist         13   15
# doctor          0    7
# educator       26   69
# engineer        2   65
# entertainment   2   16
# executive       3   29
# healthcare     11    5
# homemaker       6    1
# lawyer          2   10
# librarian      29   22
# marketing      10   16
# none            4    5
# other          36   69
# programmer      6   60
# retired         1   13
# salesman        3    9
# scientist       3   28
# student        60  136
# technician      1   26
# writer         19   26

# %%
occ_gender_count = users.pivot_table(index='occupation', columns = 'gender')
occ_gender_count
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9172\1936250168.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   occ_gender_count = users.pivot_table(index='occupation', columns = 'gender')
#                      age                user_id
# gender                 F          M           F           M
# occupation
# administrator  40.638889  37.162791  443.944444  420.069767
# artist         30.307692  32.333333  432.153846  469.000000
# doctor               NaN  43.571429         NaN  533.714286
# educator       39.115385  43.101449  454.730769  471.492754
# engineer       29.500000  36.600000  806.500000  445.553846
# entertainment  31.000000  29.000000  780.000000  350.250000
# executive      44.000000  38.172414  373.000000  427.413793
# healthcare     39.818182  45.400000  568.454545  354.000000
# homemaker      34.166667  23.000000  367.166667  898.000000
# lawyer         39.500000  36.200000  285.000000  373.900000
# librarian      40.000000  40.000000  449.137931  535.954545
# marketing      37.200000  37.875000  443.300000  434.375000
# none           36.500000  18.600000  521.750000  246.200000
# other          35.472222  34.028986  474.666667  578.246377
# programmer     32.166667  33.216667  411.166667  437.966667
# retired        70.000000  62.538462  860.000000  489.230769
# salesman       27.000000  38.555556  637.666667  447.333333
# scientist      28.333333  36.321429  611.666667  449.428571
# student        20.750000  22.669118  497.533333  479.404412
# technician     38.000000  32.961538  938.000000  480.692308
# writer         37.631579  35.346154  536.052632  466.230769

# %%
occ_gender_count['Total_Count']= occ_gender_count.loc[ : :,['F','M']].sum(axis =1)
occ_gender_count
# Out:
# gender          F    M  Total_Count
# occupation
# administrator  36   43           79
# artist         13   15           28
# doctor          0    7            7
# educator       26   69           95
# engineer        2   65           67
# entertainment   2   16           18
# executive       3   29           32
# healthcare     11    5           16
# homemaker       6    1            7
# lawyer          2   10           12
# librarian      29   22           51
# marketing      10   16           26
# none            4    5            9
# other          36   69          105
# programmer      6   60           66
# retired         1   13           14
# salesman        3    9           12
# scientist       3   28           31
# student        60  136          196
# technician      1   26           27
# writer         19   26           45

# %%
occ_gender_count['Female%'] = occ_gender_count.F / occ_gender_count.Total_Count*100
occ_gender_count['Male%'] = occ_gender_count.M / occ_gender_count.Total_Count*100
occ_gender_count
# Out:
# gender          F    M  Total_Count    Female%       Male%
# occupation
# administrator  36   43           79  45.569620   54.430380
# artist         13   15           28  46.428571   53.571429
# doctor          0    7            7   0.000000  100.000000
# educator       26   69           95  27.368421   72.631579
# engineer        2   65           67   2.985075   97.014925
# entertainment   2   16           18  11.111111   88.888889
# executive       3   29           32   9.375000   90.625000
# healthcare     11    5           16  68.750000   31.250000
# homemaker       6    1            7  85.714286   14.285714
# lawyer          2   10           12  16.666667   83.333333
# librarian      29   22           51  56.862745   43.137255
# marketing      10   16           26  38.461538   61.538462
# none            4    5            9  44.444444   55.555556
# other          36   69          105  34.285714   65.714286
# programmer      6   60           66   9.090909   90.909091
# retired         1   13           14   7.142857   92.857143
# salesman        3    9           12  25.000000   75.000000
# scientist       3   28           31   9.677419   90.322581
# student        60  136          196  30.612245   69.387755
# technician      1   26           27   3.703704   96.296296
# writer         19   26           45  42.222222   57.777778

# %%
occ_gender_count[['Female%', 'Male%']]
# Out:
# gender           Female%       Male%
# occupation
# administrator  45.569620   54.430380
# artist         46.428571   53.571429
# doctor          0.000000  100.000000
# educator       27.368421   72.631579
# engineer        2.985075   97.014925
# entertainment  11.111111   88.888889
# executive       9.375000   90.625000
# healthcare     68.750000   31.250000
# homemaker      85.714286   14.285714
# lawyer         16.666667   83.333333
# librarian      56.862745   43.137255
# marketing      38.461538   61.538462
# none           44.444444   55.555556
# other          34.285714   65.714286
# programmer      9.090909   90.909091
# retired         7.142857   92.857143
# salesman       25.000000   75.000000
# scientist       9.677419   90.322581
# student        30.612245   69.387755
# technician      3.703704   96.296296
# writer         42.222222   57.777778

# %% [markdown]
# ## Section-6: The purpose of the below exercises is to understand how to use lambda-apply-functions
# ## The below exercises (34-41) required to use student-mat.csv and student-por.csv files

# %%
student_mat = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/student-mat.csv')
student_por = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/student-por.csv')

# %% [markdown]
# ### 34. Import the datasets *student-mat* and *student-por* and append them and assigned object as df

# %%
df = pd.concat([student_mat,student_por])
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [1044 rows x 33 columns]

# %% [markdown]
# ### 35. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df = df.loc[: :,'school':'guardian']

# %% [markdown]
# ### 36. Create a lambda function that captalize strings (example: if we give at_home as input function and should give At_home as output.

# %%
capitalize_str = lambda x : x.capitalize()

# %% [markdown]
# ### 37. Capitalize both Mjob and Fjob variables using above lamdba function

# %%
df.Mjob = df['Mjob'].apply(capitalize_str)
df.Fjob = df['Fjob'].apply(capitalize_str)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      reason guardian
# 0    course   mother
# 1    course   father
# 2     other   mother
# 3      home   mother
# 4      home   father
# ..      ...      ...
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother
#
# [1044 rows x 12 columns]

# %% [markdown]
# ### 38. Print the last elements of the data set. (Last few records)

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      reason guardian
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother

# %% [markdown]
# ### 39. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
# Assigned it to the new varible so that changes will reflect in original dataset.

# %% [markdown]
# ### 40. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if x>18:
        return True
    else:
        return False
df['legal_drinker'] = [majority(x) if x>18 else majority(x) for x in df['age']]
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      reason guardian  legal_drinker
# 0    course   mother          False
# 1    course   father          False
# 2     other   mother          False
# 3      home   mother          False
# 4      home   father          False
# ..      ...      ...            ...
# 644  course   mother           True
# 645  course   mother          False
# 646  course   mother          False
# 647  course   mother          False
# 648  course   mother          False
#
# [1044 rows x 13 columns]

# %% [markdown]
# ### 41. Multiply every number of the dataset by 10.

# %%
df = df.select_dtypes(include = 'number')*10
df
# Out:
#      age  Medu  Fedu
# 0    180    40    40
# 1    170    10    10
# 2    150    10    10
# 3    150    40    20
# 4    160    30    30
# ..   ...   ...   ...
# 644  190    20    30
# 645  180    30    10
# 646  180    10    10
# 647  170    30    10
# 648  180    30    20
#
# [1044 rows x 3 columns]

# %% [markdown]
# ## Section-6: The purpose of the below exercises is to understand how to perform simple joins
# ## The below exercises (42-48) required to use cars1.csv and cars2.csv files

# %% [markdown]
# ### 42. Import the datasets cars1.csv and cars2.csv and assign names as cars1 and cars2

# %%
cars1 = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/cars1.csv')
cars2 = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/cars2.csv')

# %% [markdown]
#    ### 43. Print the information to cars1 by applying below functions
#    hint: Use different functions/methods like type(), head(), tail(), columns(), info(), dtypes(), index(), shape(), count(), size(), ndim(), axes(), describe(), memory_usage(), sort_values(), value_counts()
#    Also create profile report using pandas_profiling.Profile_Report

# %%
cars1

# %% [markdown]
# ### 44. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1 = cars1.dropna(axis=1)
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 193       1              ford maverick
# 194       1                 amc hornet
# 195       1         chevrolet chevette
# 196       1            chevrolet woody
# 197       2                  vw rabbit
#
# [198 rows x 9 columns]

# %% [markdown]
# ### 45. What is the number of observations in each dataset?

# %%
print('The number of observations in cars1 is',cars1.shape[0])
print('The number of observations in cars2 is',cars2.shape[0])
# Out:
# The number of observations in cars1 is 198
# The number of observations in cars2 is 200

# %% [markdown]
# ### 46. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.merge(cars1, cars2 ,how = 'outer')

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 47. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
rand_num = np.random.randint(15000,73000,cars.shape[0])

# %% [markdown]
# ### 48. Add the column owners to cars

# %%
cars['owners'] = rand_num
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# 0         1  chevrolet chevelle malibu   59100
# 1         1          buick skylark 320   27628
# 2         1         plymouth satellite   25099
# 3         1              amc rebel sst   39139
# 4         1                ford torino   29900
# ..      ...                        ...     ...
# 393       1            ford mustang gl   47164
# 394       2                  vw pickup   60665
# 395       1              dodge rampage   44176
# 396       1                ford ranger   64659
# 397       1                 chevy s-10   21235
#
# [398 rows x 10 columns]

# %% [markdown]
# ## Section-7: The purpose of the below exercises is to understand how to perform date time operations

# %% [markdown]
# ### 49. Write a Python script to display the
# - a. Current date and time
# - b. Current year
# - c. Month of year
# - d. Week number of the year
# - e. Weekday of the week
# - f. Day of year
# - g. Day of the month
# - h. Day of week

# %%
import time
import datetime
print('Current date and time:' ,datetime.datetime.now())
print('Current year:' ,datetime.date.today().strftime('%Y'))
print('Month of year:' ,datetime.date.today().strftime('%B'))
print('Week number of the year:' ,datetime.date.today().strftime('%W'))
print('Weekday of the week:' ,datetime.date.today().strftime('%w'))
print('Day of year:' ,datetime.date.today().strftime('%j'))
print('Day of the month:' ,datetime.date.today().strftime('%d'))
print('Day of week:' ,datetime.date.today().strftime('%A'))
# Out:
# Current date and time: 2023-06-29 10:54:32.531226
# Current year: 2023
# Month of year: June
# Week number of the year: 26
# Weekday of the week: 4
# Day of year: 180
# Day of the month: 29
# Day of week: Thursday

# %% [markdown]
# ### 50. Write a Python program to convert a string to datetime.
# Sample String : Jul 1 2014 2:43PM
#
# Expected Output : 2014-07-01 14:43:00

# %%
dt = pd.to_datetime('Jul 1 2014 2:43PM', format="%b %d %Y %I:%M%p")
dt
# Out:
# Timestamp('2014-07-01 14:43:00')

# %%
from datetime import datetime
dt = datetime.strptime('Jul 1 2014 2:43PM',"%b %d %Y %I:%M%p")
dt
# Out:
# datetime.datetime(2014, 7, 1, 14, 43)

# %% [markdown]
# ### 51. Write a Python program to subtract five days from current date.
#
# Current Date : 2015-06-22
#
# 5 days before Current Date : 2015-06-17

# %%
import datetime
dt = datetime.date.today() - datetime.timedelta(days=5)
print('Current Date' ,datetime.date.today())
print('5 days before Current Date' ,dt)
# Out:
# Current Date 2023-06-29
# 5 days before Current Date 2023-06-24

# %% [markdown]
# ### 52. Write a Python program to convert unix timestamp string to readable date.
#
# Sample Unix timestamp string : 1284105682
#
# Expected Output : 2010-09-10 13:31:22

# %%
import datetime

# Unix timestamp string
timestamp_str = '1284105682'

# Convert Unix timestamp to datetime object
timestamp = datetime.datetime.fromtimestamp(int(timestamp_str))

# Format the datetime object
formatted_date = timestamp.strftime('%Y-%m-%d %H:%M:%S')

# Print the formatted date
print("Readable Date:", formatted_date)
# Out:
# Readable Date: 2010-09-10 13:31:22

# %% [markdown]
# ### 53. Convert the below Series to pandas datetime :
#
# DoB = pd.Series(["07Sep59","01Jan55","15Dec47","11Jul42"])
#
# Make sure that the year is 19XX not 20XX

# %%
DoB = pd.Series(["07Sep59","01Jan55","15Dec47","11Jul42"])
converted_dates = pd.to_datetime(DoB, format='%d%b%y').apply(lambda x: x.replace(year=x.year - 100))
converted_dates
# Out:
# 0   1959-09-07
# 1   1955-01-01
# 2   1947-12-15
# 3   1942-07-11
# dtype: datetime64[ns]

# %% [markdown]
# ### 54. Write a Python program to get days between two dates.

# %%
from datetime import date
f_date = date(2022,6,20)
l_date = date(2022,6,29)
delta = l_date - f_date
print(delta)
# Out:
# 9 days, 0:00:00

# %% [markdown]
# ### 55. Convert the below date to datetime and then change its display format using the .dt module
#
# Date = "15Dec1989"
#
# Result : "Friday, 15 Dec 98"

# %%
# Original date string
Date = "15Dec1989"

# Convert to datetime format
date_datetime = pd.to_datetime(Date, format='%d%b%Y')

# Change display format using .dt.strftime()
formatted_date = date_datetime.dt.strftime('%A, %d %b %y')

# Print the formatted date
print(formatted_date)

# %% [markdown]
# ## The below exercises (56-66) required to use wind.data file

# %% [markdown]
# ### About wind.data:
#
# The data have been modified to contain some missing values, identified by NaN.
#
# 1. The data in 'wind.data' has the following format:

# %% [raw]
# """
# Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
# 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
# """
# The first three columns are year, month and day.  The remaining 12 columns are average windspeeds in knots at 12 locations in Ireland on that day.

# %% [markdown]
# ### 56. Import the dataset wind.data and assign it to a variable called data and replace the first 3 columns by a proper date time index

# %%
data = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/wind.data',parse_dates = [['Yr','Mo','Dy']])
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %% [markdown]
# ### 57. Year 2061 is seemingly imporoper. Convert every year which are < 70 to 19XX instead of 20XX.

# %%
data['Yr_Mo_Dy'] = np.where(data['Yr_Mo_Dy'].dt.year <2000, data.Yr_Mo_Dy, data.Yr_Mo_Dy- pd.DateOffset(years = 100))
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %%
#Rename the column Yr_Mo_Dy to Date

data.rename(columns={'Yr_Mo_Dy': 'Date'}, inplace=True)
data
# Out:
#            Date    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %% [markdown]
# ### 58. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data1 = data.set_index('Date')
data1.index.astype('datetime64[ns]')
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %% [markdown]
# ### 59. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data1.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
data1.dropna()
# Out:
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-04  10.58   6.63  11.75  4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42  6.17  10.71   8.21  11.92   6.54  10.92
# 1961-01-06  13.21   8.12   9.96  6.67   5.37   4.50  10.67   4.42   7.17
# 1961-01-07  13.50  14.29   9.50  4.96  12.29   8.33   9.17   9.29   7.58
# 1961-01-08  10.96   9.75   7.62  5.91   9.62   7.29  14.29   7.62   9.25
# ...           ...    ...    ...   ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62  8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46  5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42  8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29  9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29  9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Date
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83
# 1961-01-06   7.50   8.12  13.17
# 1961-01-07   7.96  13.96  13.79
# 1961-01-08  10.46  16.62  16.46
# ...           ...    ...    ...
# 1978-12-27  14.00  17.21  40.08
# 1978-12-28  18.05  21.79  41.46
# 1978-12-29  16.42  18.88  29.58
# 1978-12-30  12.12  14.67  28.79
# 1978-12-31  11.38  12.08  22.08
#
# [6546 rows x 12 columns]

# %% [markdown]
# ### 60. Compute how many non-missing values there are in total.

# %%
data1.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### 61. Calculate the mean windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data1.mean().mean()
# Out:
# 10.227982360836938

# %% [markdown]
# ### 62. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats = data1.describe().T[['min','max','mean','std']]
loc_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# ### 63. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats = data1.apply(['min','max','mean','std'],axis = 1).reset_index()
day_stats.head(5)
# Out:
#         Date   min    max       mean       std
# 0 1961-01-01  9.29  18.50  13.018182  2.808875
# 1 1961-01-02  6.50  17.54  11.336364  3.188994
# 2 1961-01-03  6.17  18.50  11.641818  3.681912
# 3 1961-01-04  1.79  11.75   6.619167  3.198126
# 4 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# ### 64. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
January_data = data1[data1.index.month==1]
January_data.mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### 65. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
data['Month'] = data['Date'].dt.year.astype(str) + '-' + data['Date'].dt.month.astype(str)
mean_windspeed_per_month = data.groupby('Month').mean()
mean_windspeed_per_month
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12464\3883994859.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_windspeed_per_month = data.groupby('Month').mean()
#                RPT        VAL        ROS       KIL        SHA        BIR  \
# Month
# 1961-1   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-10  14.289667  10.915806  12.236452  8.154839  11.865484   8.333871
# 1961-11  10.896333   8.592667  11.850333  6.045667   9.123667   6.250667
# 1961-12  14.973548  11.903871  13.980323  7.073871  11.323548   8.302258
# 1961-2   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# ...            ...        ...        ...       ...        ...        ...
# 1978-5    8.270645   7.226774   6.901613  3.740645   6.973871   4.449677
# 1978-6   11.386667   9.474333  10.253333  6.053000  10.395333   7.490333
# 1978-7   12.820000   9.750968   9.910323  6.483871  10.055161   7.820645
# 1978-8    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-9   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
#
#                DUB        CLA        MUL        CLO        BEL        MAL
# Month
# 1961-1   11.184839   9.245333   9.085806  10.107419  13.880968  14.703226
# 1961-10  11.194194   9.271935   8.942667  11.455806  14.229355  16.793226
# 1961-11  10.869655   6.313667   6.575000   8.383667  10.776667  12.146000
# 1961-12  11.753548   8.163226   7.965806   9.246774  12.239355  13.098710
# 1961-2   11.890714  11.846071  11.821429  12.714286  18.583214  15.411786
# ...            ...        ...        ...        ...        ...        ...
# 1978-5    5.420968   6.130645   5.742581   5.926452   9.263548  10.756452
# 1978-6    7.928000   7.802000   8.220333   7.550000  11.501000  15.078667
# 1978-7    7.831935   8.459355   8.523871   7.732903  12.648710  14.077419
# 1978-8    5.650323   5.417742   7.241290   5.536774  10.466774  12.054194
# 1978-9   10.790333   9.583000  10.069333   8.939000  15.680333  19.391333
#
# [216 rows x 12 columns]

# %%
mean_windspeed_per_month = data.groupby([data['Date'].dt.year, data['Date'].dt.month]).mean()
mean_windspeed_per_month
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12464\733409723.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_windspeed_per_month = data.groupby([data['Date'].dt.year, data['Date'].dt.month]).mean()
#                  RPT        VAL        ROS       KIL        SHA        BIR  \
# Date Date
# 1961 1     14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
#      2     16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
#      3     10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
#      4     10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
#      5      9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...              ...        ...        ...       ...        ...        ...
# 1978 8      9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
#      9     10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
#      10     9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
#      11    16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
#      12    16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
#                  DUB        CLA        MUL        CLO        BEL        MAL
# Date Date
# 1961 1     11.184839   9.245333   9.085806  10.107419  13.880968  14.703226
#      2     11.890714  11.846071  11.821429  12.714286  18.583214  15.411786
#      3      9.644194   9.829677  10.294138  11.251935  16.410968  15.720000
#      4      6.925333   7.094667   7.342333   7.237000  11.147333  10.278333
#      5      7.604000   8.177097   8.039355   8.499355  11.900323  12.011613
# ...              ...        ...        ...        ...        ...        ...
# 1978 8      5.650323   5.417742   7.241290   5.536774  10.466774  12.054194
#      9     10.790333   9.583000  10.069333   8.939000  15.680333  19.391333
#      10     8.115484   7.337742   8.297742   8.243871  13.776774  17.150000
#      11    11.492333   9.657333  10.701333  10.676000  17.404667  20.723000
#      12    12.077419  10.194839  10.616774  11.028710  13.859677  21.371613
#
# [216 rows x 12 columns]

# %% [markdown]
# ### 66. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
# resample data to 'W' week and use the functions
weekly = data.resample('W').agg(['min','max','mean','std'])

# slice it for the first 52 weeks and locations
weekly.loc[weekly.index[1:53], "RPT":"MAL"] .head(10)

# %% [markdown]
# ## The below exercises (67-70) required to use appl_1980_2014.csv  file

# %% [markdown]
# ### 67. Import the file appl_1980_2014.csv and assign it to a variable called 'apple'

# %%
apple = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/appl_1980_2014.csv')

# %% [markdown]
# ### 68.  Check out the type of the columns

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### 69. Transform the Date column as a datetime type

# %%
apple.Date = pd.to_datetime(apple.Date)
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %% [markdown]
# ### 70.  Set the date as the index

# %%
apple.set_index('Date',inplace = True)
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### 71.  Is there any duplicate dates?

# %%
duplicate_dates = apple.duplicated()

# Check if any duplicates exist
if duplicate_dates.any():
    print("There are duplicate dates in the dataset.")
else:
    print("There are no duplicate dates in the dataset.")
# Out:
# There are no duplicate dates in the dataset.

# %%
apple.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 72.  The index is from the most recent date. Sort the data so that the first entry is the oldest date.

# %%
apple = apple.sort_values(by = 'Date', ascending = True).reset_index()
apple
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 0    1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1    1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 2    1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 3    1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 4    1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...         ...    ...    ...    ...    ...        ...        ...
# 8460 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 8461 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 8462 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 8463 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 8464 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### 73. Get the last business day of each month

# %%
apple['day'] = apple['Date'].dt.day
apple.groupby([apple['Date'].dt.year , apple['Date'].dt.month_name()]).day.last()
# Out:
# Date  Date
# 1980  December    31
# 1981  April       30
#       August      31
#       December    31
#       February    27
#                   ..
# 2014  January     31
#       July         8
#       June        30
#       March       31
#       May         30
# Name: day, Length: 404, dtype: int64

# %% [markdown]
# ### 74.  What is the difference in days between the first day and the oldest

# %%
apple.index.max()-apple.index.min()
# Out:
# 8464

# %% [markdown]
# ### 75.  How many months in the data we have?

# %%
len(apple.groupby([apple['Date'].dt.year , apple['Date'].dt.month]).count())
# Out:
# 404

# %% [markdown]
# ### 76. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
plt.figure(figsize = (13.5 ,9))
plt.hist(apple['Adj Close'])
plt.show()

# %% [markdown]
# ## Section-8: The purpose of the below exercises is to understand how to create basic graphs

# %% [markdown]
# ## The below exercises (77-80) required to use Online_Retail.csv file

# %% [markdown]
# ### 77. Import the dataset from this Online_Retail.csv and assign it to a variable called online_rt

# %%
online_rt = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/Online_Retail.csv',encoding = 'windows-1252')
online_rt
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/10 8:26       2.55     17850.0  United Kingdom
# 1        12/1/10 8:26       3.39     17850.0  United Kingdom
# 2        12/1/10 8:26       2.75     17850.0  United Kingdom
# 3        12/1/10 8:26       3.39     17850.0  United Kingdom
# 4        12/1/10 8:26       3.39     17850.0  United Kingdom
# ...               ...        ...         ...             ...
# 541904  12/9/11 12:50       0.85     12680.0          France
# 541905  12/9/11 12:50       2.10     12680.0          France
# 541906  12/9/11 12:50       4.15     12680.0          France
# 541907  12/9/11 12:50       4.15     12680.0          France
# 541908  12/9/11 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### 78. Create a barchart with the 10 countries that have the most 'Quantity' ordered except UK

# %%
# group by the Country
# sort the value and get the first 10 after UK

country = online_rt.groupby('Country').agg({'Quantity':'sum'}).sort_values('Quantity',ascending = False).iloc[1:11]
plt.figure(figsize = (10,5))
sns.barplot(x = country.index, y= 'Quantity' , data =country)

""""
countries = online_rt.groupby('Country').sum()
countries = countries.sort_values(by = 'Quantity',ascending = False)[1:11]

# create the plot
countries['Quantity'].plot(kind='bar')

# Set the title and labels
plt.xlabel('Countries')
plt.ylabel('Quantity')
plt.title('10 Countries with most orders')

# show the plot
plt.show()
"""
# Out:
# <Axes: xlabel='Country', ylabel='Quantity'>

# %% [markdown]
# ### 79.  Exclude negative Quatity entries

# %%
online_rt1 = online_rt[(online_rt.Quantity >0)]
online_rt1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/10 8:26       2.55     17850.0  United Kingdom
# 1        12/1/10 8:26       3.39     17850.0  United Kingdom
# 2        12/1/10 8:26       2.75     17850.0  United Kingdom
# 3        12/1/10 8:26       3.39     17850.0  United Kingdom
# 4        12/1/10 8:26       3.39     17850.0  United Kingdom
# ...               ...        ...         ...             ...
# 541904  12/9/11 12:50       0.85     12680.0          France
# 541905  12/9/11 12:50       2.10     12680.0          France
# 541906  12/9/11 12:50       4.15     12680.0          France
# 541907  12/9/11 12:50       4.15     12680.0          France
# 541908  12/9/11 12:50       4.95     12680.0          France
#
# [531285 rows x 8 columns]

# %% [markdown]
# ### 80. Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries
# Hint: First we need to find top-3 countries based on revenue, then create scater plot between Quantity and Unitprice for each country separately

# %%
customers = online_rt.groupby(['CustomerID','Country']).sum()

customers = customers[customers.UnitPrice > 0]

customers['Country'] = customers.index.get_level_values(1)

top_countries =  ['Netherlands', 'EIRE', 'Germany']

customers = customers[customers['Country'].isin(top_countries)]

#Graph
g = sns.FacetGrid(customers, col="Country")
g.map(plt.scatter, "Quantity", "UnitPrice", alpha=1)
g.add_legend()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12464\3133456704.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   customers = online_rt.groupby(['CustomerID','Country']).sum()

# %% [markdown]
# ## The below exercises (81-90) required to use FMCG_Company_Data_2019.csv file

# %% [markdown]
# ### 81. Import the dataset FMCG_Company_Data_2019.csv and assign it to a variable called company_data

# %%
company_data = pd.read_csv('C:/Users/user/Downloads/Analytics Lab Class Files/Python/Case Study/Basic Data Manipulation - Visualization Exercise/2. Basic Data Manipulation - Visualization Exercise/Exercise Data Files/FMCG_Company_Data_2019.csv')
company_data
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
#     Total_Units  Total_Revenue  Total_Profit
# 0         21100        3584890        211000
# 1         18330        2864979        183300
# 2         22470        4058082        224700
# 3         22270        2890646        222700
# 4         20960        2997280        209600
# 5         20140        2857866        201400
# 6         29550        5735655        295500
# 7         36140        5196932        361400
# 8         23400        3060720        234000
# 9         26670        4661916        266700
# 10        41280        6794688        412800
# 11        30020        3770512        300200

# %% [markdown]
# ### 82. Create line chart for Total Revenue of all months with following properties
# - X label name = Month
# - Y label name = Total Revenue

# %%
plt.figure(figsize = (10,6))
plt.plot(company_data.Month ,company_data.Total_Revenue, marker = 'o')
plt.xlabel('Month')
plt.ylabel('Total_Revenue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 83. Create line chart for Total Units of all months with following properties
# - X label name = Month
# - Y label name = Total Units
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.

# %%
plt.figure(figsize = (10,6))
plt.plot(company_data.Month ,company_data.Total_Units,label='Total Units for each month', linestyle = 'dotted',color ='r',marker = 'o')
plt.xlabel('Month')
plt.ylabel('Total_Units')
plt.legend(loc='lower right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 84. Read all product sales data (Facecream, FaceWash, Toothpaste, Soap, Shampo, Moisturizer) and show it  using a multiline plot
# - Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
plt.figure(figsize = (15,6))
plt.plot(company_data.Month ,company_data.FaceCream,label='FaceCream',marker = 'o')
plt.plot(company_data.Month ,company_data.FaceWash,label='FaceWash',marker = 'o')
plt.plot(company_data.Month ,company_data.ToothPaste,label='ToothPaste',marker = 'o')
plt.plot(company_data.Month ,company_data.Soap,label='Soap',marker = 'o')
plt.plot(company_data.Month ,company_data.Shampo,label='Shampo',marker = 'o')
plt.plot(company_data.Month ,company_data.Moisturizer,label='Moisturizer',marker = 'o')
plt.xlabel('Month')
plt.ylabel('Number of Units sold')
plt.legend(loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 85. Create Bar Chart for soap of all months and Save the chart in folder

# %%
a = pd.pivot_table(data = company_data, index = 'Month', values = 'Soap').plot( kind ='bar', figsize = (15,6))
for i in a.containers:
    a.bar_label(i,size = 15,label_type ='center')
plt.legend(bbox_to_anchor = (1.12,1))

# %% [markdown]
# ### 86. Create Stacked Bar Chart for Soap, Shampo, ToothPaste for each month
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
month_list = company_data.Month.tolist()
Soap_sales_Data = company_data.Soap.tolist()
Shampo_sales_Data = company_data.Shampo.tolist()
ToothPaste_sales_Data = company_data.ToothPaste.tolist()

plt.plot([],[],color='m',label='Soap',linewidth = 5)
plt.plot([],[],color='c',label='Shampo',linewidth = 5)
plt.plot([],[],color='r',label='ToothPaste',linewidth = 5)

plt.stackplot(month_list,Soap_sales_Data,Shampo_sales_Data,ToothPaste_sales_Data, colors = ['m','c','r'])

plt.xlabel('Month Number')
plt.ylabel('Sales Units in Number')
plt.title('All Products sales data using stack plot')
plt.legend(loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 87. Create Histogram for Total Revenue

# %%
plt.hist(company_data.Total_Revenue,bins =20)
plt.xlabel('Total_Revenue')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 88. Calculate total sales data (quantity) for 2019 for each product and show it using a Pie chart. Understand percentage contribution from each product

# %%
month_list = company_data.Month.tolist()
labels = ['FaceCream','FaceWash','ToothPaste','Soap','Shampo','Moisturizer']
salesData = [company_data['FaceCream'].sum(),company_data['FaceWash'].sum(),company_data['ToothPaste'].sum(),company_data['Soap'].sum(),company_data['Shampo'].sum(),company_data['Moisturizer'].sum()]
plt.axis('equal')
plt.pie(salesData,labels = labels ,autopct='%1.1f%%')
plt.title('Sales Data')
plt.legend(loc='lower right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 89. Create line plots for Soap & Facewash of all months in a single plot using Subplot

# %%
f, axes = plt.subplots(1,2,figsize = (20,5))
axes[0].plot(company_data.Month ,company_data.Soap,label='Soap',marker = 'o')
axes[0].set_title('Soap sold per month')
axes[1].plot(company_data.Month ,company_data.FaceWash,label='FaceWash',marker = 'o')
axes[1].set_title('FaceWash sold per month')
plt.show()

# %% [markdown]
# ### 90. Create Box Plot for Total Profit variable

# %%
company_data.Total_Profit.plot(kind = 'box')
# Out:
# <Axes: >
